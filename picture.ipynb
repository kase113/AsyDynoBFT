# %%
# figure 1 n=16
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

tps_list = [
    [960.4685336290952,13309.364317336936,9684.476891828554],
    [1894.528942135908,23331.77189685733,17784.056132237685],
    [2802.744281551559,30509.56417742599,23974.74051790485],
    [3684.0323566581296,36103.21976277223,32198.876029511746],
    [4582.248429150268,40234.079568555106,36039.503565574145]
]
data_value = np.asarray(tps_list)
batch_list = [1000, 2000, 3000, 4000, 5000]
batch = np.asarray(batch_list)
data = pd.DataFrame(data_value, batch, columns=["hbbft", "dumbo", "hbbft_shard"])


# data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
# figure 1 n=32
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

tps_list = [
    [525.4240771182856,8733.209261010974,18388.613235779205],
    [1041.941608135314,14785.61397876356,33471.850801228014],
    [1551.0117100600169,20962.211221128964,47526.51374045922],
    [2050.3572362389277,25128.257220399337,58582.917915914586],
    [2548.627690746302,28892.086691550252,70208.45425150557]
]
data_value = np.asarray(tps_list)
batch_list = [1000, 2000, 3000, 4000, 5000]
batch = np.asarray(batch_list)
data = pd.DataFrame(data_value, batch, columns=["hbbft", "dumbo", "hbbft_shard"])


# data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
# figure 1 n=64
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

tps_list = [
    [525.4240771182856,8733.209261010974,18388.613235779205],
    [1041.941608135314,14785.61397876356,33471.850801228014],
    [1551.0117100600169,20962.211221128964,47526.51374045922],
    [2050.3572362389277,25128.257220399337,58582.917915914586],
    [2548.627690746302,28892.086691550252,70208.45425150557]
]
data_value = np.asarray(tps_list)
batch_list = [1000, 2000, 3000, 4000, 5000]
batch = np.asarray(batch_list)
data = pd.DataFrame(data_value, batch, columns=["hbbft", "dumbo", "hbbft_shard"])


# data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)

# %%
# figure3 n=16
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

consus = [
    [16.658536370311463,0.9016208222934177,1.6226261769022257],
    [16.890742225306376,1.0286402638469423, 1.7832987861973901],
    [17.126071870326996,1.1799578581537518,1.9127273900168285],
    [17.372268700173922,1.329521309052195,1.9876470203910555],
    [17.458678034799437,1.329521309052195,2.1801473604781285]
]
data_value = np.asarray(consus)
# batch_list = [16, 32, 64, 96]
# tps_list = [999.344651271388,4776.674911356351,17784.056132237685,30785.888498003704, 40453.59206446519]
tps_list = [999.344651271388,13551.868286753004, 23974.74051790485, 32198.876029511746, 40453.59206446519]
tps = np.asarray(tps_list)
data = pd.DataFrame(data_value, tps, columns=["hbbft", "dumbo", "hbbft_shard"])


sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
# figure3 n=32
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

consus = [
    [60.90318543357508,2.7481306450707574,1.7402073549372807],
    [61.423787571489804,3.246398835309914, 1.877910583146981],
    [61.895083948969834,3.4347521471125737,1.9568024809871403],
    [62.428145562963834,3.8204002433589532,2.116657968078341],
    [62.77888315383876,4.153386402343001,2.2382326860513007]
]
data_value = np.asarray(consus)
# batch_list = [16, 32, 64, 96]
# tps_list = [999.344651271388,4776.674911356351,17784.056132237685,30785.888498003704, 40453.59206446519]
tps_list = [538.7433607184222,14995.414256313847, 21002.571350271493, 29291.45895795729, 35104.22712575278]
tps = np.asarray(tps_list)
data = pd.DataFrame(data_value, tps, columns=["hbbft", "dumbo", "hbbft_shard"])


sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
# figure3 n=64
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

consus = [
    [244.919255970312,14.096137822738712,5.786953553557396],
    [243.70304444858004,19.094323391360888, 5.966551923326083],
    [245.77374432661705,24.17023477330804,6.166811612035547],
    [248.54674225194114,29.282109898115912,6.4847138704998155],
    [253.3399740340455,34.50407603276628,6.778022644775255]
]
data_value = np.asarray(consus)
# batch_list = [16, 32, 64, 96]
# tps_list = [999.344651271388,4776.674911356351,17784.056132237685,30785.888498003704, 40453.59206446519]
tps_list = [262.07208735221656,6000, 12000, 18000, 23500.321942491217]
tps = np.asarray(tps_list)
data = pd.DataFrame(data_value, tps, columns=["hbbft", "dumbo", "hbbft_shard"])


sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
# figure3 n=96
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

consus = [
    [567.8822805310286,35.73368356270448,5.644461487020765],
    [575.0567894191258,43.72275981981131, 5.884233549662998],
    [575.1481525003913,51.94507109231892,6.159126467364176],
    [581.3153836957756,60.267124857669494,6.4384654658181315],
    [589.3519345812853,68.59302657452368,6.744186418397083]
]
data_value = np.asarray(consus)
# batch_list = [16, 32, 64, 96]
# tps_list = [999.344651271388,4776.674911356351,17784.056132237685,30785.888498003704, 40453.59206446519]
tps_list = [161.94605735777483,2500, 5000, 7500, 9885.056926186153]
tps = np.asarray(tps_list)
data = pd.DataFrame(data_value, tps, columns=["hbbft", "dumbo", "hbbft_shard"])


sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
# figure4_2 n=64
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

consus = [
    [64000.0,48000.0,8000.0],
    [128000.0,96000.0, 16000.0],
    [192000.0,144000.0,23785.71428571429],
    [256000.0,192000.0,32000.0],
    [320000.0,240000.0,39821.42857142858]
]
data_value = np.asarray(consus)
# batch_list = [16, 32, 64, 96]
# tps_list = [999.344651271388,4776.674911356351,17784.056132237685,30785.888498003704, 40453.59206446519]
tps_list = [200,1875, 3150, 1675, 6500]
tps = np.asarray(tps_list)
data = pd.DataFrame(data_value, tps, columns=["hbbft", "dumbo", "hbbft_shard"])


sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
# figure4_2 n=96
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

consus = [
    [91285.71428571438,72000.0,8000.0],
    [192000.0,144000.0, 16000.0],
    [288000.0,216000.0,24000.0],
    [382857.1428571425,288000.0,32000.0],
    [480000.0,360000.0,40000.0]
]
tps = [
    [161.94605735777483,,],
    
]

data_value = np.asarray(consus)
# batch_list = [16, 32, 64, 96]
# tps_list = [999.344651271388,4776.674911356351,17784.056132237685,30785.888498003704, 40453.59206446519]
tps_list = [200,1875, 3150, 1675, 6500]
tps = np.asarray(tps_list)
data = pd.DataFrame(data_value, tps, columns=["hbbft", "dumbo", "hbbft_shard"])


sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>
